# %%
import time

print("Please insert your card:")
time.sleep(2)
password=123
pin=int(input("inter your atm pin:"))

balance=1000
transactions = [] 

if pin==password:
    while True:
        
        print("""
              1 == balance
              2 == withdraw amount
              3 == deposit balance
              4 == mini Satement
              5 == exit
              """)
        try:
            option=int(input("please enter your choise:"))
        except:
              print("Plese enter vaild option")

        if option ==1:
              print(f"your current balance is {balance}")

        if option ==2:
              withdraw_amount=int(input("Please enter withdraw amount"))
              balance = balance-withdraw_amount
            
              print(f"{withdraw_amount} is debited from your account")
                
              print(f"your updated Balance is {balance}")
            
        if option ==3:
            
            deposit_amount=int(input("Please enter deposit_amount"))
            balance = balance + deposit_amount
                
            print(f"{deposit_amount} is credit to your account")
            print(f"your updated Balance is {balance}")
                
        if option==4:
            print("Mini Statement:")
            for t in transactions[-5:]:
                print("-",t)
            print(f"Current balance: {balance}")
            
            
                 
        if option ==5:
            
            print("Thank you for useing the ATM")
            break

else:
    print("wrong pin please try again")
# Out:
# Please insert your card:
# inter your atm pin:123
#
#               1 == balance
#               2 == withdraw amount
#               3 == deposit balance
#               4 == mini Satement
#               5 == exit
#
# please enter your choise:1
# your current balance is 1000
#
#               1 == balance
#               2 == withdraw amount
#               3 == deposit balance
#               4 == mini Satement
#               5 == exit
#
# please enter your choise:2
# Please enter withdraw amount300
# 300 is debited from your account
# your updated Balance is 700
#
#               1 == balance
#               2 == withdraw amount
#               3 == deposit balance
#               4 == mini Satement
#               5 == exit
#
# please enter your choise:3
# Please enter deposit_amount500
# 500 is credit to your account
# your updated Balance is 1200
#
#               1 == balance
#               2 == withdraw amount
#               3 == deposit balance
#               4 == mini Satement
#               5 == exit
#
# please enter your choise:4
# Mini Statement:
# Current balance: 1200
#
#               1 == balance
#               2 == withdraw amount
#               3 == deposit balance
#               4 == mini Satement
#               5 == exit

# %% [markdown]
# #
